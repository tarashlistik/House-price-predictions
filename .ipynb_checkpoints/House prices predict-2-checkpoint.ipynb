# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
train_data = pd.read_csv('/Users/admin/Downloads/house-prices-advanced-regression-techniques/data/train.csv')

# %%
test_data = pd.read_csv("/Users/admin/Downloads/house-prices-advanced-regression-techniques/data/test.csv")

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train_data = train_data[['SalePrice', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
                        'CentralAir', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'BsmtQual',
                        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces',
                        'GarageArea', 'GarageCars', 'TotalBsmtSF']]

# %%
test_data = test_data[['LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
                        'CentralAir', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'BsmtQual',
                        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces',
                        'GarageArea', 'GarageCars', 'TotalBsmtSF']]

# %%
train_data = train_data.fillna(0)

# %%
test_data = test_data.fillna(0)

# %%
test_data['KitchenQual'] = test_data['KitchenQual'].replace({'TA': 1, 'Gd': 2, 'Ex': 3, 'Fa': 4})
train_data['KitchenQual'] = train_data['KitchenQual'].replace({'TA': 1, 'Gd': 2, 'Ex': 3, 'Fa': 4})

# %%
test_data['CentralAir'] = test_data['CentralAir'].replace({'Y': 1, 'N': 2})
train_data['CentralAir'] = train_data['CentralAir'].replace({'Y': 1, 'N': 2})

# %%
test_data['BsmtQual'] = test_data['BsmtQual'].replace({'TA': 1, 'Gd': 2, 'Ex': 3, 'Fa': 4})
train_data['BsmtQual'] = train_data['BsmtQual'].replace({'TA': 1, 'Gd': 2, 'Ex': 3, 'Fa': 4})

# %%
test_data['KitchenQual'].unique()
# Out:
# array([1, 2, 3, 4, 0])

# %%
train_data.columns
# Out:
# Index(['SalePrice', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'CentralAir', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtQual', 'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageArea', 'GarageCars', 'TotalBsmtSF'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    SalePrice  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  CentralAir  \
# 0     208500     8450       2003          2003       196.0           1
# 1     181500     9600       1976          1976         0.0           1
# 2     223500    11250       2001          2002       162.0           1
# 3     140000     9550       1915          1970         0.0           1
# 4     250000    14260       2000          2000       350.0           1
#
#    1stFlrSF  2ndFlrSF  GrLivArea  BsmtFullBath  BsmtQual  FullBath  \
# 0       856       854       1710             1         2         2
# 1      1262         0       1262             0         2         2
# 2       920       866       1786             1         2         2
# 3       961       756       1717             1         1         1
# 4      1145      1053       2198             1         2         2
#
#    KitchenQual  TotRmsAbvGrd  Fireplaces  GarageArea  GarageCars  TotalBsmtSF
# 0            2             8           0         548           2          856
# 1            1             6           1         460           2         1262
# 2            2             6           1         608           2          920
# 3            2             7           1         642           3          756
# 4            2             9           1         836           3         1145

# %%
corr = train_data.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', square=True)
plt.title('Гістограма кореляції')
plt.show()

# %%
# train_data_linear = train_data.iloc[:, :16]

# %%
sns.histplot(train_data['GrLivArea'], kde=True) 

plt.xlabel('GrLivArea')
plt.ylabel("Частота")
plt.title(f"Розподіл {'GrLivArea'}")

plt.show()
# Out:
# /Users/admin/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/admin/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.regplot(data=train_data, x='GrLivArea', y='SalePrice', scatter_kws={'alpha':0.3})

plt.xlabel('Overall Condition')
plt.ylabel('Sale Price')
plt.title('Залежність між GrLivArea і SalePrice')

plt.show()

# %%
X_train_logist = train_data.drop(['SalePrice'], axis=1)
y_train_logist = train_data.SalePrice

# %%
# sp_columns = ['LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'TotRmsAbvGrd', 'TotalBsmtSF']
# scaler = StandardScaler()

# for column in sp_columns:
#     X_train_logist[[column]] = scaler.fit_transform(X_train_logist[[column]])

# %%
X_train_logist.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  MasVnrArea  CentralAir  1stFlrSF  \
# 0     8450       2003          2003       196.0           1       856
# 1     9600       1976          1976         0.0           1      1262
# 2    11250       2001          2002       162.0           1       920
# 3     9550       1915          1970         0.0           1       961
# 4    14260       2000          2000       350.0           1      1145
#
#    2ndFlrSF  GrLivArea  BsmtFullBath  BsmtQual  FullBath  KitchenQual  \
# 0       854       1710             1         2         2            2
# 1         0       1262             0         2         2            1
# 2       866       1786             1         2         2            2
# 3       756       1717             1         1         1            2
# 4      1053       2198             1         2         2            2
#
#    TotRmsAbvGrd  Fireplaces  GarageArea  GarageCars  TotalBsmtSF
# 0             8           0         548           2          856
# 1             6           1         460           2         1262
# 2             6           1         608           2          920
# 3             7           1         642           3          756
# 4             9           1         836           3         1145

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_logist, y_train_logist, test_size=0.2, random_state=42)

# %%
model_logistic = LogisticRegression()
model_linear= LinearRegression()

# %%
model_logistic.fit(X_train, y_train)
# Out:
# /Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_logistic.score(X_train, y_train)
# Out:
# 0.036815068493150686

# %%
model_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_linear.score(X_train, y_train)
# Out:
# 0.7667018483385402

# %%
model_RFR = RandomForestRegressor()
model_DTR = DecisionTreeRegressor()

# %%
param_grid_RFR = {
    'n_estimators': [400, 500, 600],
    'max_depth': [20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'max_features': ['log2', 'sqrt'],
    'random_state': [42]
}
param_grid_DTR = {
    'max_depth': [20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2'],
    'random_state': [42]
}

# %%
grid_search_RFR = GridSearchCV(estimator=model_RFR, param_grid=param_grid_RFR, cv=5, scoring='neg_mean_squared_error')
grid_search_DTR = GridSearchCV(estimator=model_DTR, param_grid=param_grid_DTR, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search_RFR.fit(X_train, y_train)
grid_search_DTR.fit(X_train, y_train)
# Out:
# /Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/admin/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [            nan             nan             nan -2.43366510e+09
#  -1.96977233e+09 -2.25749755e+09 -2.43366510e+09 -1.96977233e+09
#  -2.25749755e+09             nan             nan             nan
#  -1.98269061e+09 -2.05360983e+09 -2.27753453e+09 -1.98269061e+09
#  -2.05360983e+09 -2.27753453e+09             nan             nan
#              nan -1.98269061e+09 -2.05360983e+09 -2.27753453e+09
#  -1.98269061e+09 -2.05360983e+09 -2.27753453e+09]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [20, 30, 40],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'random_state': [42]},
#              scoring='neg_mean_squared_error')

# %%
best_params_RFR = grid_search_RFR.best_params_
best_params_DTR = grid_search_DTR.best_params_

# %%
best_params_RFR
# Out:
# {'max_depth': 30,
#  'max_features': 'log2',
#  'min_samples_split': 5,
#  'n_estimators': 400,
#  'random_state': 42}

# %%
optimal_model_RFR = RandomForestRegressor(**best_params_RFR)
optimal_model_DTR = DecisionTreeRegressor(**best_params_DTR)

# %%
optimal_model_RFR.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, max_features='log2', min_samples_split=5,
#                       n_estimators=400, random_state=42)

# %%
optimal_model_DTR.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, max_features='sqrt', min_samples_split=5,
#                       random_state=42)

# %%
optimal_model_RFR.score(X_train, y_train)
# Out:
# 0.96105452378655

# %%
optimal_model_DTR.score(X_train, y_train)
# Out:
# 0.9702677573739719

# %%
predictions = optimal_model_RFR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, predictions)
mse
# Out:
# 931825696.0006573

# %%
feature_importances = optimal_model_RFR.feature_importances_
feature_names = X_train.columns 

plt.figure(figsize=(10, 6))
plt.title("Важливість ознак в моделі Random Forest")
plt.barh(range(len(feature_importances)), feature_importances, align="center")
plt.yticks(range(len(feature_importances)), feature_names)
plt.xlabel("Важливість ознак")
plt.ylabel("Ознаки")
plt.gca().invert_yaxis()  

plt.show()

# %%
predict_test_data = optimal_model_RFR.predict(test_data)

# %%
predict_test_data
# Out:
# array([124165.74746347, 146515.26851804, 184889.02428571, ...,
#        165656.6093195 , 122054.41213023, 227533.91295464])

# %%
sample_submition = pd.read_csv("/Users/admin/Downloads/house-prices-advanced-regression-techniques/data/sample_submission.csv")

# %%
test_data['SalePrice'] = predict_test_data

# %%
test_data.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  MasVnrArea  CentralAir  1stFlrSF  \
# 0    11622       1961          1961         0.0           1       896
# 1    14267       1958          1958       108.0           1      1329
# 2    13830       1997          1998         0.0           1       928
# 3     9978       1998          1998        20.0           1       926
# 4     5005       1992          1992         0.0           1      1280
#
#    2ndFlrSF  GrLivArea  BsmtFullBath  BsmtQual  FullBath  KitchenQual  \
# 0         0        896           0.0         1         1            1
# 1         0       1329           0.0         1         1            2
# 2       701       1629           0.0         2         2            1
# 3       678       1604           0.0         1         2            2
# 4         0       1280           0.0         2         2            2
#
#    TotRmsAbvGrd  Fireplaces  GarageArea  GarageCars  TotalBsmtSF  \
# 0             5           0       730.0         1.0        882.0
# 1             6           0       312.0         1.0       1329.0
# 2             6           1       482.0         2.0        928.0
# 3             7           1       470.0         2.0        926.0
# 4             5           0       506.0         2.0       1280.0
#
#        SalePrice
# 0  124165.747463
# 1  146515.268518
# 2  184889.024286
# 3  182950.789101
# 4  183860.968708

# %%
SalePrice_2 = test_data['SalePrice'].to_csv('ML Project House Prices_XGB.csv')
